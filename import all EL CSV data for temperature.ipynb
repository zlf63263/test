# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate

from scipy.signal import savgol_filter

from math import log


import os,glob

from scipy.stats import linregress

from csv import reader


#********************************************
# select the reference spectrum at room temperature as y_LED_ref_filter


x_LED_ref = []                            #list to hold captured words
y_LED_ref = []
with open('/Users/lucas/Google Drive/data/Pulsed LED/20210323 pulsed EL spectra for temperature/0.7M MAPbI3 30ns EL for temperature/12V10ns9Hz 2021 March 23 19_48_05 006.csv', 'r') as f:        #open the file for reading
    csv_reader = reader(f)
    header = next(csv_reader)
    # Iterate over each row in the csv using reader object
    for row in csv_reader:
        # row variable is a list that represents a row in csv
        x_LED_ref.append(row[0])
        y_LED_ref.append(row[1])

#         x_LED_ref.append(line[0]) #add to the list last word
#         y_LED_ref.append(line[1]) #add to the list last word



x_LED_ref=[float(i) for i in x_LED_ref]
y_LED_ref=[float(i) for i in y_LED_ref]

 

length=len(x_LED_ref)


bgtemp=[0]
for i in range(length):
    if y_LED_ref[i]<0:
        bgtemp.append(y_LED_ref[i])
    
bg=min(bgtemp)

for i in range(length):
    y_LED_ref[i]=y_LED_ref[i]-bg
    
    
    
maxLED=max(y_LED_ref)






for i in range(length):
    if maxLED==0:
        pass
    else:
        y_LED_ref[i]=y_LED_ref[i]/maxLED

y_LED_ref_filter = savgol_filter(y_LED_ref, 51, 3) # window size 51, polynomial order 3

y_LED_ref_filter=[float(i) for i in y_LED_ref_filter]
plt.figure()
#*****************************************

#Export all files in the folder, as y_LED_filter

folder_path = '/Users/lucas/Google Drive/data/Pulsed LED/20210323 pulsed EL spectra for temperature/0.7M MAPbI3 30ns EL for temperature/'


count_file=0

Temperature_extracted=[]

for filename in glob.glob(os.path.join(folder_path, '*.csv')):
    x_LED = []                            #list to hold captured words
    y_LED = []   
        
    with open(filename, 'r') as f:
        csv_reader = reader(f)
        header = next(csv_reader)
    # Iterate over each row in the csv using reader object
        for row in csv_reader:
        # row variable is a list that represents a row in csv
            x_LED.append(row[0])
            y_LED.append(row[1])
            
    
    x_LED=[float(i) for i in x_LED]
    y_LED=[float(i) for i in y_LED]
    
    
    
    count_file=count_file+1
    
    save_file_path=os.path.join(folder_path,'processed data')
 
            

    
    
    
    length=len(x_LED)
    
    
    
    bgtemp=[0]
    for i in range(length):
        if y_LED[i]<0:
            bgtemp.append(y_LED[i])
    
    bg=min(bgtemp)

    for i in range(length):
        y_LED[i]=y_LED[i]-bg
    
    

    maxLED=max(y_LED)
    
    Ex_LED=np.zeros(length)
    

    for i in range(length):
        if maxLED==0:
            pass
        else:
            y_LED[i]=y_LED[i]/maxLED # normalize spectrum
            Ex_LED[i]=1240/x_LED[i]
        
        

    y_LED_filter = savgol_filter(y_LED, 51, 3) # window size 51, polynomial order 3, smooth data
    y_LED_filter=[float(i) for i in y_LED_filter]

    
    temp=np.zeros(length)
    for i in range(length):
        if y_LED_ref_filter[i]<0 or y_LED_filter[i]<0:
            pass
        else:
            temp[i]=log(y_LED_ref_filter[i]/y_LED_filter[i])
    
    
    res = [idx for idx, val in enumerate(Ex_LED) if 1.70 > val > 1.66] 
    
    Ex_LED_fit=[]
    y_LED_fit=[]
    temp_fit=[]
    for j in res:
        Ex_LED_fit.append(Ex_LED[j])
        y_LED_fit.append(y_LED[j])
        temp_fit.append(temp[j])
   


    slope, intercept, r_value, p_value, std_err = linregress(Ex_LED_fit, temp_fit)
    
    T_ref=300

    Kb=8.61733326e-5
    T_pulse=1/(slope*Kb+1/T_ref)-273.15
    
    Temperature_extracted.append(T_pulse)
    
    print (count_file)
    print (filename)
    print (T_pulse)
    
#     with open(os.path.join(save_file_path,'count.txt'), "a") as myfile:
#         myfile.write(str(count_file)+"\n")
#         myfile.write(filename+"\n")  
#         myfile.write(str(T_pulse)+"\n")
#         myfile.write("\n")

        
        
#     with open(os.path.join(save_file_path,'{0}.txt').format(count_file), "w") as f:
#         for s in y_LED_filter:
#             f.write(str(s) +"\n")

#     with open(os.path.join(save_file_path,'{0}.txt').format(count_file), "w") as f:
#         for s in x_LED:
#             f.write(str(s) +"\n")

    plt.plot(Ex_LED_fit, temp_fit, 'r')
    
    plt.legend(['raw', 'filtered', 'True'])
    #plt.axis([-0.05, 6.33, -1.05, 1.05])
    plt.title('ln')
    plt.show()
    
    plt.figure()
    # plt.plot(x_LED, y_LED, 'r')
    plt.plot(Ex_LED, y_LED, 'r', Ex_LED, y_LED_filter, 'b')
    plt.legend(['raw', 'filtered', 'True'])
    #plt.axis([-0.05, 6.33, -1.05, 1.05])
    plt.title('Cubic-spline interpolation')
    plt.show()    

# with open(os.path.join(save_file_path,'temperature.txt'), "w") as myfile:
#     myfile.write(str(Temperature_extracted)+"\n")  
print(Temperature_extracted)
# Out:
# 1
# /Users/lucas/Google Drive/data/Pulsed LED/20210323 pulsed EL spectra for temperature/0.7M MAPbI3 30ns EL for temperature/bg 2021 March 23 19_40_06 001.csv
# 807.0647186566129
# 2
# /Users/lucas/Google Drive/data/Pulsed LED/20210323 pulsed EL spectra for temperature/0.7M MAPbI3 30ns EL for temperature/30V30ns2Hz 2021 March 23 19_52_04 015.csv
# 28.275482568207508
# 3
# /Users/lucas/Google Drive/data/Pulsed LED/20210323 pulsed EL spectra for temperature/0.7M MAPbI3 30ns EL for temperature/85V30ns2Hz 2021 March 23 19_55_27 022.csv
# 75.94386384479185
# 4
# /Users/lucas/Google Drive/data/Pulsed LED/20210323 pulsed EL spectra for temperature/0.7M MAPbI3 30ns EL for temperature/12V10ns9Hz 2021 March 23 19_48_02 005.csv
# 33.0248310051453
# 5
# /Users/lucas/Google Drive/data/Pulsed LED/20210323 pulsed EL spectra for temperature/0.7M MAPbI3 30ns EL for temperature/10V10ns9Hz 2021 March 23 19_48_38 007.csv
# 66.75538821882435
# 6
# /Users/lucas/Google Drive/data/Pulsed LED/20210323 pulsed EL spectra for temperature/0.7M MAPbI3 30ns EL for temperature/12V5ns9Hz 2021 March 23 19_45_24 003.csv
# 98.60035650356906
# 7
# /Users/lucas/Google Drive/data/Pulsed LED/20210323 pulsed EL spectra for temperature/0.7M MAPbI3 30ns EL for temperature/40V30ns2Hz 2021 March 23 19_52_59 017.csv
# 34.2267404484478
# 8
# /Users/lucas/Google Drive/data/Pulsed LED/20210323 pulsed EL spectra for temperature/0.7M MAPbI3 30ns EL for temperature/12V5ns9Hz 2021 March 23 19_47_35 004.csv
# 92.12886278488122
# 9
# /Users/lucas/Google Drive/data/Pulsed LED/20210323 pulsed EL spectra for temperature/0.7M MAPbI3 30ns EL for temperature/bg 2021 March 23 19_40_32 002.csv
# 584.8325818216344
# 10
# /Users/lucas/Google Drive/data/Pulsed LED/20210323 pulsed EL spectra for temperature/0.7M MAPbI3 30ns EL for temperature/14V30ns2Hz 2021 March 23 19_49_48 008.csv
# 19.144639783721345
# 11
# /Users/lucas/Google Drive/data/Pulsed LED/20210323 pulsed EL spectra for temperature/0.7M MAPbI3 30ns EL for temperature/10V5ns18Hz 2021 March 23 19_44_48 002.csv
# 145.59506461803193
# 12
# /Users/lucas/Google Drive/data/Pulsed LED/20210323 pulsed EL spectra for temperature/0.7M MAPbI3 30ns EL for temperature/55V30ns2Hz 2021 March 23 19_54_10 019.csv
# 50.075833705840466
# 13
# /Users/lucas/Google Drive/data/Pulsed LED/20210323 pulsed EL spectra for temperature/0.7M MAPbI3 30ns EL for temperature/115V30ns2Hz 2021 March 23 19_56_19 024.csv
# 95.2900360301258
# 14
# /Users/lucas/Google Drive/data/Pulsed LED/20210323 pulsed EL spectra for temperature/0.7M MAPbI3 30ns EL for temperature/18V30ns2Hz 2021 March 23 19_50_53 011.csv
# 16.0110657673751
# 15
# /Users/lucas/Google Drive/data/Pulsed LED/20210323 pulsed EL spectra for temperature/0.7M MAPbI3 30ns EL for temperature/135V30ns2Hz 2021 March 23 19_56_37 025.csv
# 109.42104353701109
# 16
# /Users/lucas/Google Drive/data/Pulsed LED/20210323 pulsed EL spectra for temperature/0.7M MAPbI3 30ns EL for temperature/25V30ns2Hz 2021 March 23 19_51_39 014.csv
# 20.445516240643826
# 17
# /Users/lucas/Google Drive/data/Pulsed LED/20210323 pulsed EL spectra for temperature/0.7M MAPbI3 30ns EL for temperature/bg 2021 March 23 19_40_45 004.csv
# 823.7658512547492
# 18
# /Users/lucas/Google Drive/data/Pulsed LED/20210323 pulsed EL spectra for temperature/0.7M MAPbI3 30ns EL for temperature/12V10ns9Hz 2021 March 23 19_48_05 006.csv
# 26.850000000000023
# 19
# /Users/lucas/Google Drive/data/Pulsed LED/20210323 pulsed EL spectra for temperature/0.7M MAPbI3 30ns EL for temperature/65V30ns2Hz 2021 March 23 19_54_35 020.csv
# 58.96524902754294
# 20
# /Users/lucas/Google Drive/data/Pulsed LED/20210323 pulsed EL spectra for temperature/0.7M MAPbI3 30ns EL for temperature/75V30ns2Hz 2021 March 23 19_55_05 021.csv
# 67.65480155342345
# 21
# /Users/lucas/Google Drive/data/Pulsed LED/20210323 pulsed EL spectra for temperature/0.7M MAPbI3 30ns EL for temperature/16V30ns2Hz 2021 March 23 19_50_07 009.csv
# 15.456164949490073
# 22
# /Users/lucas/Google Drive/data/Pulsed LED/20210323 pulsed EL spectra for temperature/0.7M MAPbI3 30ns EL for temperature/35V30ns2Hz 2021 March 23 19_52_37 016.csv
# 30.199265768060343
# 23
# /Users/lucas/Google Drive/data/Pulsed LED/20210323 pulsed EL spectra for temperature/0.7M MAPbI3 30ns EL for temperature/95V30ns2Hz 2021 March 23 19_55_48 023.csv
# 83.64343907699669
# 24
# /Users/lucas/Google Drive/data/Pulsed LED/20210323 pulsed EL spectra for temperature/0.7M MAPbI3 30ns EL for temperature/20V30ns2Hz 2021 March 23 19_51_23 013.csv
# 18.76659520210319
# 25
# /Users/lucas/Google Drive/data/Pulsed LED/20210323 pulsed EL spectra for temperature/0.7M MAPbI3 30ns EL for temperature/45V30ns2Hz 2021 March 23 19_53_44 018.csv
# 39.457058836046144
# 26
# /Users/lucas/Google Drive/data/Pulsed LED/20210323 pulsed EL spectra for temperature/0.7M MAPbI3 30ns EL for temperature/18V30ns2Hz 2021 March 23 19_51_02 012.csv
# 17.02322677481311
# 27
# /Users/lucas/Google Drive/data/Pulsed LED/20210323 pulsed EL spectra for temperature/0.7M MAPbI3 30ns EL for temperature/bg 2021 March 23 19_40_35 003.csv
# 686.3516895944817
# [807.0647186566129, 28.275482568207508, 75.94386384479185, 33.0248310051453, 66.75538821882435, 98.60035650356906, 34.2267404484478, 92.12886278488122, 584.8325818216344, 19.144639783721345, 145.59506461803193, 50.075833705840466, 95.2900360301258, 16.0110657673751, 109.42104353701109, 20.445516240643826, 823.7658512547492, 26.850000000000023, 58.96524902754294, 67.65480155342345, 15.456164949490073, 30.199265768060343, 83.64343907699669, 18.76659520210319, 39.457058836046144, 17.02322677481311, 686.3516895944817]

# %%
wavelength=[400,500,600]



real=[2,50,100]

measured=[2,30,50]


index=[0,1,2]

for j in [0,1,2]:
    real[j]=real[j]*3

factor=[0,0,0]

calibrated=[0,0,0]
raw=[4,6,8]


# for i in [0,1,2,3]:
factor[0]=real[0]/measured[0]
factor[1]=real[1]/measured[1]
factor[2]=real[2]/measured[2]


calibrated[0]=raw[0]*factor[0]   
calibrated[1]=raw[1]*factor[1]   
calibrated[2]=raw[2]*factor[2]   

print (calibrated)
# Out:
# [12.0, 30.0, 48.0]
